# %% [markdown]
# # Ficha de Expressões Regulares 1

# %% [markdown]
# ### Conceitos básicos de expressões regulares
#
# - `a` - corresponde a uma ocorrência do caracter `a`.
# - `a?` - corresponde a 0 ou 1 ocorrências do caracter `a`.
# - `a+` - corresponde a 1 ou mais ocorrências do caracter `a`.
# - `a*` - corresponde a 0 ou mais ocorrências do caracter `a`.
# - `[abc]` - corresponde a uma ocorrência de um dos caracteres `a`, `b` ou `c`.
# - `[a-z]` - corresponde a uma ocorrência de um caracter entre `a` e `z`.
# - `^` - corresponde ao início da string.
# - `$` - corresponde ao fim da string.
# - `[^abc]` - corresponde a uma ocorrência de qualquer caracter que não seja `a`, `b` ou `c`.
#
# Podemos usar o operador de união para unir várias expressões regulares. Por exemplo: `a|bbb|[^a-z]`, que corresponde a uma das várias (neste caso, 3) expressões regulares que fazem parte da união.
#
# Podemos simplificar expressões regulares como `bbb` para `b{3}`, ou seja, 3 ocorrências consecutivas do caracter `b`, neste caso. Outras opções incluem `b{3,}` para 3 ou mais ocorrências ou `b{3,6}` para entre 3 a 6 ocorrências, por exemplo.
#
# Para formar grupos de expressões regulares, usamos parênteses. Por exemplo: `((abc)*|[0-9]+)?`. Os operadores após um grupo atuam sobre o grupo.
#
# Podemos ainda aplicar modificadores a grupos. Por exemplo, `(?i:teste)` corresponde à expressão "teste", escrita com qualquer combinação de maiúsculas e minúsculas (e.g., "TESTE", "tEsTe", "TEste", etc.).

# %% [markdown]
# ## Exercício 1

# %% [markdown]
# ### Alínea 1.1
#
# Dada uma linha de texto, define um programa que determina se a palavra "hello" aparece no início da linha.
#
# Conceitos importantes para este exercício:
#
# - `re.match(pattern, string[, flags])` - analisa a `string` e tenta encontrar uma correspondência para a expressão regular `pattern` a partir do início da string. Devolve `None` se não encontrar nenhuma correspondência.
# - `r""` - string correspondente a uma expressão regular.

# %%
line1 = "hello world"
line2 = "goodbye world"
line3 = "hi, hello there"

import re 
#como o match apenas procura no inicio da string e é isso que queremos basta por apenas a string que queremos
palavra=re.match(r"hello",line2)
if palavra:
    print("A palavra 'hello' aparece no início da linha.")
else:
    print("A palavra 'hello' NÃO aparece no início da linha")
# Out:
# A palavra 'hello' NÃO aparece no início da linha

# %% [markdown]
# ### Alínea 1.2
#
# Dada uma linha de texto, define um programa que determina se a palavra "hello" aparece em qualquer posição da linha.
#
# Conceitos importantes para este exercício:
#
# - `re.search(pattern, string[, flags])` - analisa a `string` e tenta encontrar uma correspondência para a expressão regular `pattern` em qualquer posição da string. Devolve `None` se não encontrar nenhuma correspondência.

# %%
line1 = "hello world"
line2 = "goodbye world"
line3 = "hi, hello there"

#adicionado o \b no inicio e no fim para apenas encontrar a palavra hello e nao palavras que contenham a string hello
#o search encontra apenas a primeira ocorrencia
palavra = re.search(r"\bhello\b",line3)
if palavra:
    print("A palavra 'hello' está presente na linha.")
else:
    print("A palavra 'hello' NÃO esta presente na linha.")
# Out:
# A palavra 'hello' está presente na linha.

# %% [markdown]
# ### Alínea 1.3
#
# Dada uma linha de texto, define um programa que pesquisa por todas as ocorrências da palavra "hello" dentro da linha, admitindo que a palavra seja escrita com maiúsculas ou minúsculas.
#
# Conceitos importantes para este exercício:
#
# - `re.findall(pattern, string[, flags])` - encontra todas as correspondências que não se sobreponham da expressão regular `pattern` na `string`. Devolve uma lista.

# %%
line = "Hello there! Uh, hi, hello, it's me... Heyyy, hello? HELLO!"
line2 = "Hello there! Uh, hi, hellohello, it's me... Heyyy, hello? HELLO!"#adicionado

#para encontrar caso seja maiuscula ou minuscula usamos o (?i:palavra)
#\b para dar apenas a palavra hello e nao palavras que contenham hello

palavra = re.findall(r"\b(?i:hello)\b",line2)
print(palavra)

import re

# Tambem podemos usar com flags
palavra = re.findall(r"\bhello\b", line2, re.IGNORECASE)
print(palavra)
# Out:
# ['Hello', 'hello', 'HELLO']
# ['Hello', 'hello', 'HELLO']

# %% [markdown]
# ### Alínea 1.4
#
# Dada uma linha de texto, define um programa que pesquisa por todas as ocorrências da palavra "hello" dentro da linha, substituindo cada uma por "\*YEP\*".
#
# Conceitos importantes para este exercício:
#
# - `re.sub(pattern, replacement, string, count = 0, flags = 0)` - substitui todas as correspondências da expressão regular `pattern` na `string` por `replacement`. `replacement` pode ser uma string, uma expressão regular ou uma função que recebe uma correspondência e devolve uma string. O parâmetro `count` determina o limite de substituições (por defeito é 0, ou seja, não há limite).

# %%
line = "Hello there! Uh, hi, hello, it's me... Heyyy, hello? HELLO!"
line2 = "Hello there! Uh, hi, hellohello, it's me... Heyyy, hello? HELLO!"#adicionado

print(re.sub(r"\b(?i:hello)\b","*YEP*",line))
#com flag
print(re.sub(r"\bhello\b","*YEP*",line,flags=re.IGNORECASE))
# Out:
# *YEP* there! Uh, hi, *YEP*, it's me... Heyyy, *YEP*? *YEP*!
# *YEP* there! Uh, hi, *YEP*, it's me... Heyyy, *YEP*? *YEP*!

# %% [markdown]
# ### Alínea 1.5
#
# Dada uma linha de texto, define um programa que pesquisa por todas as ocorrências do caracter vírgula, separando cada parte da linha por esse caracter.
#
# Conceitos importantes para este exercício:
#
# - `re.split(pattern, string, maxsplit = 0, flags = 0)` - divide a `string` com base nas correspondências da expressão regular `pattern`. O parâmetro `maxsplit` pode ser usado para definir um limite de divisões (por defeito é 0, que corresponde a divisões infinitas).

# %%
line = "bananas, laranjas, maçãs, uvas, melancias, cerejas, kiwis, etc."

#\s* retira os espaços depois da virgula (\s espaço em branco, * 0 ou mais)
re.split(r",\s*",line)
# Out:
# ['bananas',
#  'laranjas',
#  'maçãs',
#  'uvas',
#  'melancias',
#  'cerejas',
#  'kiwis',
#  'etc.']

# %% [markdown]
# ## Exercício 2
#
# Define a função `palavra_magica` que recebe uma frase e determina se a mesma termina com a expressão "por favor", seguida de um sinal válido de pontuação.

# %%
#os unicos sinais de pontuação validos para terminar uma frase sao .!?
#para identificar o fim da string usamos $
#adicionado \s* para dar em casos em que o sinal esteja separado por espaços (0 ou mais)
def palavra_magica(frase):
  palavra=re.search(r"por favor\s*[.!?]\s*$",frase)
  return palavra


print(palavra_magica("Posso ir à casa de banho, por favor?"))
print(palavra_magica("Posso ir à casa de banho, por favor ?"))
print(palavra_magica("Preciso de um favor."))
# Out:
# <re.Match object; span=(26, 36), match='por favor?'>
# <re.Match object; span=(26, 37), match='por favor ?'>
# None

# %% [markdown]
# ## Exercício 3
#
# Define a função `narcissismo` que calcula quantas vezes a palavra "eu" aparece numa string.

# %%
#\b para encontrar apenas a palavra eu
#a flag para ignorar maiusculas e minusculas
def narcissismo(linha):
  lista = re.findall(r"\beu\b",linha,re.IGNORECASE)
  return len(lista)

print(narcissismo("Eu não sei se eu quero continuar a ser eu. Por outro lado, eu ser eu é uma parte importante de quem EU sou."))
# Out:
# 6

# %% [markdown]
# ## Exercício 4
#
# Define a função `troca_de_curso` que substitui todas as ocorrências de "LEI" numa linha pelo nome do curso dado à função.

# %%
#\b para apenas substituir LEI
#neste caso é case sensitive, porque a palavra lei tem outro significado
def troca_de_curso(linha, novo_curso):
  return re.sub(r"\bLEI\b",novo_curso,linha)


print(troca_de_curso("LEI é o melhor curso! Adoro LEI! Gostar de LEI devia ser uma lei.","LEB"))
# Out:
# LEB é o melhor curso! Adoro LEB! Gostar de LEB devia ser uma lei.

# %% [markdown]
# ## Exercício 5
#
# Define a função `soma_string` que recebe uma string com vários números separados por uma vírgula (e.g., "1,2,3,4,5") e devolve a soma destes números.

# %%
def soma_string(linha):
  lista= re.split(r",",linha)
  soma=0
  for n in lista:
    n=int(n)
    soma+=n
  return soma

#com sum e em compreensao de listas
def soma_string_sum(linha):
  return sum(int(n) for n in re.split(r",",linha))

print(soma_string("4,-6,2,3,8,-3,0,2,-5,1"))
print(soma_string_sum("4,-6,2,3,8,-3,0,2,-5,1"))
# Out:
# 6
# 6

# %% [markdown]
# ## Exercício 6
#
# Define a função `pronomes` que encontra e devolve todos os pronomes pessoais presentes numa frase, i.e., "eu", "tu", "ele", "ela", etc., com atenção para letras maiúsculas ou minúsculas.

# %%
def pronomes(linha):
    #\b para dar apenas os pronomes e não palavras com os pronomes
    #(?:) para agrupar as palavras e garantir que se aplica a todas
    return re.findall(r"\b(?:eu|tu|el[ea]s?|nós|vós)\b",linha,re.IGNORECASE)

print(pronomes("Ola, eu estouela com ela, e Eles não vós"))
# Out:
# ['eu', 'ela', 'Eles', 'vós']

# %% [markdown]
# ## Exercício 7
#
# Define a função `variavel_valida` que recebe uma string e determina se a mesma é um nome válido para uma variável, ou seja, se começa por uma letra e apenas contém letras, números ou *underscores*.

# %%
def variavel_valida(string):
    #usa-se [a-z] em vez de \D porque isso tambem inclui o _ (apenas esta em minusculas porque é ignorado case)
    #o \w inclui letras, numeros e _
    # * 0 ou mais ocorrencias de \w 
    #para que a string apenas tenha o que é exigido antes temos de garantir que ela acaba depois disso
    palavra = re.match(r"^[a-z]\w*$",string,re.IGNORECASE)
    if palavra:
        return print("A string é valida")
    else:
        return print("A string NÃO é valida")
    
variavel_valida("ola")
# Out:
# A string é valida

# %% [markdown]
# ## Exercício 8
#
# Define a função `inteiros` que devolve todos os números inteiros presentes numa string. Um número inteiro pode conter um ou mais dígitos e pode ser positivo ou negativo.

# %%
def inteiros(string):
    #usamos + e nao * porque queremos que tenha pelo menos um digito
    #neste caso não existe numeros maiusculos ou minusculos, logo, nao é necessario usar flag
    #tambem nao existe palavras validas com numeros no meio logo, nao é necessario fazer o \b antes e depois
    numeros= re.findall(r"-?\d+", string)
    return numeros

frase = "Ola, em 2025 no dia 6 eram -6h"

print(inteiros(frase))
# Out:
# ['2025', '6', '-6']

# %% [markdown]
# ## Exercício 9
#
# Define a função `underscores` que substitui todos os espaços numa string por *underscores*. Se aparecerem vários espaços seguidos, devem ser substituídos por apenas um *underscore*.

# %%
def underscores(string):
    #nova_string = re.sub(r" +","_",string)
    #forma mais correta porque substitui todos os espaços
    nova_string = re.sub(r"\s+", "_",string)
    return nova_string
frase= "Ola     , estou na universidade    do Minho "
frase2= "Ola , estou   na univerisade \n do Minho"
print(underscores(frase))
print(underscores(frase2))
# Out:
# Ola_,_estou_na_universidade_do_Minho_
# Ola_,_estou_na_univerisade_do_Minho

# %% [markdown]
# ## Exercício 10
#
# Define a função `codigos_postais` que recebe uma lista de códigos postais válidos e divide-os com base no hífen. A função deve devolver uma lista de pares.

# %%
lista = [
    "4700-000",
    "1234-567",
    "8541-543",
    "4123-974",
    "9481-025"
]

def codigos_postais(lista):
    lista_final=[]
    for codigo in lista:
        separado = re.split(r"-",codigo)
        lista_final.append(separado)
    return lista_final

#para listas em compreensao

def codigos_postais_compreensao(lista):
    return [re.split("-",codigo) for codigo in lista]

print(codigos_postais(lista))
print(codigos_postais_compreensao(lista))
# Out:
# [['4700', '000'], ['1234', '567'], ['8541', '543'], ['4123', '974'], ['9481', '025']]
# [['4700', '000'], ['1234', '567'], ['8541', '543'], ['4123', '974'], ['9481', '025']]
